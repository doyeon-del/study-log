# %% [markdown]
# # F. 시계열
#
# 작업형 1유형 연습 — 포함: T1-17, T1-18, T1-19, T1-22, T1-29, T1-30, T1-33
#
# > 데이터는 seaborn/sklearn 내장셋(titanic, tips, penguins 등)으로 대체해 연습.
# > 문제 지문은 원문 복붙 대신 **본인 말로 요약**해서 적기 (출처: dataq 체험환경 / 캐글 등).

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## T1-17 시계열 1 (datetime)
#
# **문제 요약(본인 말로):**
#
# **풀이 메모:**

# %%
# T1-17 시계열 1 (datetime)

# %% [markdown]
# ## T1-18 시계열 2 (평일/주말)
#
# **문제 요약(본인 말로):**
#
# **풀이 메모:**

# %%
# T1-18 시계열 2 (평일/주말)

# %% [markdown]
# ## T1-19 시계열 3 (월별 총계)
#
# **문제 요약(본인 말로):**
#
# **풀이 메모:**

# %%
# T1-19 시계열 3 (월별 총계)

# %% [markdown]
# ## T1-22 시계열 (Weekly)
#
# **문제 요약(본인 말로):**
#
# **풀이 메모:**

# %%
# T1-22 시계열 (Weekly)

# %% [markdown]
# ## T1-29 날짜 형식 변환
#
# **문제 요약(본인 말로):**
#
# **풀이 메모:**

# %%
# T1-29 날짜 형식 변환

# %% [markdown]
# ## T1-30 시계열 비율 계산
#
# **문제 요약(본인 말로):**
#
# **풀이 메모:**

# %%
# T1-30 시계열 비율 계산

# %% [markdown]
# ## T1-33 Timedelta 계산
#
# **문제 요약(본인 말로):**
#
# **풀이 메모:**

# %%
# T1-33 Timedelta 계산
